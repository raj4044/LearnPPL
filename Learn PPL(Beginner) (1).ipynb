# %%
x=13
y=10
x+y
# Out:
# 23

# %%
x-y
# Out:
# 3

# %%
x*y
# Out:
# 130

# %%
x/y
# Out:
# 1.3

# %%
x%y
# Out:
# 3

# %%
x==y
# Out:
# False

# %%
x<y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x>y and x<=y
# Out:
# False

# %%
x>y and x>=y and x!=y
# Out:
# True

# %%
x>y or x<=y
# Out:
# True

# %%
x>y and x>=y
# Out:
# True

# %%
x<y and x<=y
# Out:
# False

# %%
not x>y
# Out:
# False

# %%
x
# Out:
# 13

# %%
x+=3

# %%
x
# Out:
# 16

# %%
x-=4

# %%
x
# Out:
# 12

# %%
x*=y

# %%
x
# Out:
# 120

# %%
x/=z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-eaadac52117c> in <module>
# ----> 1 x/=z
#
# NameError: name 'z' is not defined

# %%
z=20

# %%
x/=z

# %%
x
# Out:
# 6.0

# %%
a=35
b=24
c=8
d=a+c-b
print(d)
# Out:
# 19

# %%
'''
This is a program for calculating the total number of buses at a depot.
'''
no_of_arrived_buses=35
no_of_departed_buses=24
initial_no_of_buses=8
current_buses=initial_no_of_buses+no_of_arrived_buses-no_of_departed_buses
print('current number of buses are', current_buses)
#end of code
# Out:
# current number of buses are 19
