# %%
str1 = 'Hello Folks!'
str2 = "Welcome to DTA Python tutorial"
str3 = """Happy 'LEARNING' friends"""          #some strings declared
str4 = '''10'''
str5 = '30.03'

# %%
type(str1)
# Out:
# str

# %%
type(str3)
# Out:
# str

# %%
type(str4)
# Out:
# str

# %%
type(str5)
# Out:
# str

# %%
str1+str2
# Out:
# 'Hello Folks!Welcome to DTA Python tutorial'

# %%
str4+str5
# Out:
# '1030.03'

# %%
str5-str4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d518fb7437c7> in <module>
# ----> 1 str5-str4
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
str3*str4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c234c41cf77a> in <module>
# ----> 1 str3*str4
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
str3*3
# Out:
# "Happy 'LEARNING' friendsHappy 'LEARNING' friendsHappy 'LEARNING' friends"

# %%
str4+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ef338846ddb9> in <module>
# ----> 1 str4+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
str5+'10'
# Out:
# '30.0310'

# %%
int(str1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-96962c76182f> in <module>
# ----> 1 int(str1)
#
# ValueError: invalid literal for int() with base 10: 'Hello Folks!'

# %%
int(str4)
# Out:
# 10

# %%
int(str5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-bed79e465551> in <module>
# ----> 1 int(str5)
#
# ValueError: invalid literal for int() with base 10: '30.03'

# %%
float(str5)
# Out:
# 30.03

# %%
str1
# Out:
# 'Hello Folks!'

# %%
len(str1)
# Out:
# 12

# %%
len(str2)
# Out:
# 30

# %%
len(str3)
# Out:
# 24

# %%
len(str4)
# Out:
# 2

# %%
len(str5)
# Out:
# 5

# %%
str1+=' Where are you?'
str1
# Out:
# 'Hello Folks! Where are you?'

# %%
str2+=str3
str2
# Out:
# "Welcome to DTA Python tutorialHappy 'LEARNING' friends"

# %%
str4*=9
str4
# Out:
# '101010101010101010'

# %%
list(str1)
# Out:
# ['H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  'F',
#  'o',
#  'l',
#  'k',
#  's',
#  '!',
#  ' ',
#  'W',
#  'h',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'y',
#  'o',
#  'u',
#  '?']

# %%
str1[5]
# Out:
# ' '

# %%
str1[10]
# Out:
# 's'

# %%
str1[5:]
# Out:
# ' Folks! Where are you?'

# %%
str1[::-1]
# Out:
# '?uoy era erehW !skloF olleH'

# %%
str4
# Out:
# '101010101010101010'

# %%
str3
# Out:
# "Happy 'LEARNING' friends"

# %%
(str4[0]).isdigit()
# Out:
# True

# %%
str3[0].isdigit()
# Out:
# False

# %%
str3[3].isalpha()
# Out:
# True

# %%
str3.index('L')
# Out:
# 7

# %%
'101' in str4
# Out:
# True

# %%
'folk' in str1
# Out:
# False

# %%
str1
# Out:
# 'Hello Folks! Where are you?'

# %%
str1.upper()
# Out:
# 'HELLO FOLKS! WHERE ARE YOU?'

# %%
str2.lower()
# Out:
# "welcome to dta python tutorialhappy 'learning' friends"
