# %%
lst1=list()

# %%
lst2=[]

# %%
set1=set()

# %%
tuple1=('Ram',21,'Male','Ramji@london.wale')

# %%
dict1={}

# %%
type(lst1)
# Out:
# list

# %%
type(lst2)
# Out:
# list

# %%
type(set1)
# Out:
# set

# %%
type(dict1)
# Out:
# dict

# %%
lst1.append(12)

# %%
lst1.append('Rajneesh')

# %%
lst1.append(['Kumar','Sharma'])

# %%
lst1
# Out:
# [12, 'Rajneesh', ['Kumar', 'Sharma']]

# %%
lst2.append('Welcome')
lst2.append(2)
lst2.append(('DipTech', 'Academy'))
lst2
# Out:
# ['Welcome', 2, ('DipTech', 'Academy')]

# %%
set1.add('Version')
set1.add('Python')
set1.add('Python')
set1.add(3)
set1
# Out:
# {3, 'Python', 'Version'}

# %%
tuple1.add(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-8703a16932a2> in <module>
# ----> 1 tuple1.add(3)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
dict1[1]='Rajneesh'
dict1[2]='You'
dict1[3]='DTA'
dict1
# Out:
# {1: 'Rajneesh', 2: 'You', 3: 'DTA'}

# %%
lst1[2]
# Out:
# ['Kumar', 'Sharma']

# %%
lst2[1]
# Out:
# 2

# %%
tuple1[3]
# Out:
# 'Ramji@london.wale'

# %%
dict1[3]
# Out:
# 'DTA'

# %%
set1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f6f64d0ccb0e> in <module>
# ----> 1 set1[2]
#
# TypeError: 'set' object is not subscriptable

# %%
tuple(lst1)
# Out:
# (12, 'Rajneesh', ['Kumar', 'Sharma'])

# %%
list(tuple1)
# Out:
# ['Ram', 21, 'Male', 'Ramji@london.wale']

# %%
set(lst1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-57deefa174fd> in <module>
# ----> 1 set(lst1)
#
# TypeError: unhashable type: 'list'

# %%
list(set1)
# Out:
# ['Python', 3, 'Version']

# %%
len(lst1)
# Out:
# 3

# %%
len(set1)
# Out:
# 3

# %%
len(tuple1)
# Out:
# 4

# %%
len(dict1)
# Out:
# 3

# %%
lst1
# Out:
# [12, 'Rajneesh', ['Kumar', 'Sharma']]

# %%
lst2
# Out:
# ['Welcome', 2, ('DipTech', 'Academy')]

# %%
lst3=[1, 54, 'abc', '@#$', 255, '123', 'DTA', 'DipTech', 'Academy']

# %%
len(lst3)
# Out:
# 9

# %%
lst3[1:9:2]
# Out:
# [54, '@#$', '123', 'DipTech']

# %%
lst3[2:]
# Out:
# ['abc', '@#$', 255, '123', 'DTA', 'DipTech', 'Academy']

# %%
lst3[2:5]
# Out:
# ['abc', '@#$', 255]

# %%
lst3[:5]
# Out:
# [1, 54, 'abc', '@#$', 255]

# %%
lst3[::2]
# Out:
# [1, 'abc', 255, 'DTA', 'Academy']

# %%
lst3[::-2]
# Out:
# ['Academy', 'DTA', 255, 'abc', 1]

# %%
lst3.index('DTA')
# Out:
# 6

# %%
lst4=lst1+lst3
lst4
# Out:
# [12,
#  'Rajneesh',
#  ['Kumar', 'Sharma'],
#  1,
#  54,
#  'abc',
#  '@#$',
#  255,
#  '123',
#  'DTA',
#  'DipTech',
#  'Academy']

# %%
name,age,sex,mail=tuple1

# %%
name
# Out:
# 'Ram'

# %%
age
# Out:
# 21

# %%
sex
# Out:
# 'Male'

# %%
mail
# Out:
# 'Ramji@london.wale'
