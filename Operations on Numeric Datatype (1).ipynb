# %% [markdown]
# # Operations on Numberic Datatype in Python

# %%
#Arithmetic Operations

# %%
num1=10          #Number 1
num2=20          #Number 2
float1=3.14      #Float 1                      declare some variable to perform operations
float2=2.71      #float 2
complex1= 1+2j   #complex 1
complex2= 2-3j   #complex 2

# %%
#find datatypes

# %%
type(num1)
# Out:
# int

# %%
type(float1)
# Out:
# float

# %%
type(complex1)
# Out:
# complex

# %%
#Arithmetic operations

# %%
add=num1+num2
add
# Out:
# 30

# %%
type(add)
# Out:
# int

# %%
sub=num1-num2
sub
# Out:
# -10

# %%
mul=num1*num2
mul
# Out:
# 200

# %%
div=num1/num2
div
# Out:
# 0.5

# %%
type(div)
# Out:
# float

# %%
int_div=num1//num2
int_div
# Out:
# 0

# %%
power=num1**num2
power
# Out:
# 100000000000000000000

# %%
type(power)
# Out:
# int

# %%
complex1+complex2
# Out:
# (3-1j)

# %%
complex1-complex2
# Out:
# (-1+5j)

# %%
complex1*complex2
# Out:
# (8+1j)

# %%
num1*float1
# Out:
# 31.400000000000002

# %%
num2+float2
# Out:
# 22.71

# %%
num1/float1
# Out:
# 3.184713375796178

# %%
num1+complex1
# Out:
# (11+2j)

# %%
num2*complex2
# Out:
# (40-60j)

# %%
float1-complex1
# Out:
# (2.14-2j)

# %%
float2/complex2
# Out:
# (0.41692307692307695+0.6253846153846154j)

# %%
float2**num1
# Out:
# 21364.508628553813

# %%
2**8
# Out:
# 256

# %%
num1//float1
# Out:
# 3.0

# %%
num1+=3
num1
# Out:
# 13

# %%
num2*=num1
num2
# Out:
# 260

# %%
comp3=complex(num1)
comp3
# Out:
# (13+0j)

# %%
float3=float(num2)
float3
# Out:
# 260.0

# %%
num3=int(float1)
num3
# Out:
# 3

# %%
num4=int(complex1)
num4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-f585d0864fe4> in <module>
# ----> 1 num4=int(complex1)
#       2 num4
#
# TypeError: can't convert complex to int

# %%
import random

# %%
random.randint(100,200)
# Out:
# 143

# %%
random.randint(100,200)
# Out:
# 105

# %%
random.randrange(0,100,2)
# Out:
# 26

# %%
random.randrange(0,100,2)
# Out:
# 76

# %%
random.randrange(100,200,7)
# Out:
# 107
