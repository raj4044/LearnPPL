# %%
x=13
y=10
x+y
# Out:
# 23

# %%
x-y
# Out:
# 3

# %%
x*y
# Out:
# 130

# %%
x/y
# Out:
# 1.3

# %%
x%y
# Out:
# 3

# %%
x==y
# Out:
# False

# %%
x<y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x>y and x<=y
# Out:
# False

# %%
x>y and x>=y and x!=y
# Out:
# True

# %%
x>y or x<=y
# Out:
# True

# %%
x>y and x>=y
# Out:
# True

# %%
x<y and x<=y
# Out:
# False

# %%
not x>y
# Out:
# False
